# %%
from scipy.stats import chi2_contingency

# %%
#defining table
data = [[14,4],[0,10]]

_, p, dof, expected = chi2_contingency(data)

# %%
expected
# Out:
# array([[9., 9.],
#        [5., 5.]])

# %%
#p value(0.0003857467556820071)
#chances are very low that null hypothesis is true
#i. e. 'athelete' and 'smoker' are related to each other.
p
# Out:
# np.float64(0.0003857467556820071)

# %%
dof   #degrees of freedom
# Out:
# 1
